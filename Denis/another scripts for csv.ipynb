# %%
import pandas as pd
import itertools
from bs4 import BeautifulSoup as b
import os
with open('senses.A.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")

'''
senses = soup.find_all('relation')
for_csv = pd.DataFrame()
for i in range(len(senses)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\synset_relations.N.csv" , encoding='utf-8', header=True, index=False)
'''
# Out:
# '\nsenses = soup.find_all(\'relation\')\nfor_csv = pd.DataFrame()\nfor i in range(len(senses)):\n    if i%1000 == 0:\n        print(i)\n    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)\nfor_csv.to_csv(os.getcwd()+"\\synset_relations.N.csv" , encoding=\'utf-8\', header=True, index=False)\n'

# %%
with open('senses.A.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")
senses = soup.find_all('sense')
for_csv = pd.DataFrame()
for i in range(len(senses)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\senses.A.csv" , encoding='utf-8-sig', header=True, index=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000

# %%
with open('senses.N.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")
senses = soup.find_all('sense')
for_csv = pd.DataFrame()
for i in range(len(senses)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\senses.N.csv" , encoding='utf-8-sig', header=True, index=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000

# %%
with open('senses.V.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")
senses = soup.find_all('sense')
for_csv = pd.DataFrame()
for i in range(len(senses)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\senses.V.csv" , encoding='utf-8-sig', header=True, index=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000

# %%
with open('synsets.A.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")

# %%
synsets = soup.find_all('synset')

# %%
synsets[0]
# Out:
# <synset definition="оборонительный доспех из продетых друг в друга железных колец" id="126480-A" part_of_speech="Adj" ruthes_name="КОЛЬЧУГА">
# <sense id="126480-A-182891">ПАНЦИРНЫЙ</sense>
# <sense id="126480-A-172706">КОЛЬЧУЖНЫЙ</sense>
# </synset>

# %%
synsets[0].find_all('sense')
# Out:
# [<sense id="126480-A-182891">ПАНЦИРНЫЙ</sense>,
#  <sense id="126480-A-172706">КОЛЬЧУЖНЫЙ</sense>]

# %%
with open('synsets.N.xml', "r", encoding='utf-8-sig') as f: # opening xml file
    content = f.read()
soup = b(content, "lxml")

synsets = soup.find_all('synset')
'''
for_csv = pd.DataFrame()
for i in range(len(senses)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\senses.V.csv" , encoding='utf-8-sig', header=True, index=False)
'''
# Out:
# '\nsenses = soup.find_all(\'sense\')\nfor_csv = pd.DataFrame()\nfor i in range(len(senses)):\n    if i%1000 == 0:\n        print(i)\n    for_csv = for_csv.append(senses[i].attrs, ignore_index=True)\nfor_csv.to_csv(os.getcwd()+"\\senses.V.csv" , encoding=\'utf-8-sig\', header=True, index=False)\n'

# %%
synsets = soup.find_all('synset')

# %%
for_csv = pd.DataFrame()
for i in range(len(synsets)):
    if i%1000 == 0:
        print(i)
    for_csv = for_csv.append(synsets[i].attrs, ignore_index=True)
for_csv.to_csv(os.getcwd()+"\\synsets.N.csv" , encoding='utf-8-sig', header=True, index=False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000

# %%
for_csv.to_csv(os.getcwd()+"\\synsets.N.csv" , encoding='utf-8-sig', header=True, index=False)

# %%
4
# Out:
# 0        147272-N
# 1          7331-N
# 2        133812-N
# 3        106097-N
# 4        132584-N
#            ...
# 29291    139506-N
# 29292      7224-N
# 29293      7736-N
# 29294    145414-N
# 29295      3949-N
# Name: id, Length: 29296, dtype: object
