# %%
import pandas as pd
import wikipediaapi
from tqdm import tqdm

# %%
import os

# %%
import urllib.request
import re
import argparse
import sys
from bs4 import BeautifulSoup
import pandas as pd
import unittest


def f(x):
    return x[0] + x[1] + x[2]


def create_request(corpus, request, case):
    url = 'http://search2.ruscorpora.ru/search.xml?env=alpha&mycorp=&mysent=&mysize=&mysentsize=&mydocsize=&dpp=&spp=&spd=&' \
          'text=lexform&mode=%s&sort=gr_tagging&lang=ru&nodia=1&req=%s&gramm1=%s&sem1=&sem-m' \
          'od1=sem&sem-mod1=sem2&flags1=&m1=&parent2=0&level2=0&min2=1&max2=1&lex2=&gramm2=&sem2=&sem-mod2=sem&se' \
          'm-mod2=sem2&flags2=&m2=&out=%s'
    common_url = url % (corpus, request, case, 'kwic')
    return common_url


def get_all_pages(common_url, results):
    pages = results // 10
    k = 0
    massive_of_links = []
    while k < pages:
        page = common_url + '&p=' + str(k)
        massive_of_links.append(page)
        k += 1
    return massive_of_links


def get_table(urls, n_results, write, kwic):
    center_right_list = []
    gram_list =[]
    center_list = []
    right_list = []
    left_list = []
    for url in urls:
        soup_url = urllib.request.urlopen(url)
        soup = BeautifulSoup(soup_url, 'lxml')
        for center_right in soup.select('tr > td > nobr'):
            center_right_list.append(center_right.text)
        for left in soup.select('tr > td > div > nobr'):
            left_list.append(left.text)
    center_list = center_right_list[0::2]
    right_list = center_right_list[1::2]
    if n_results == '':
        n_results = int(len(right_list))
    d = {"center": center_list[:n_results], "right": right_list[:n_results], "left": left_list[:n_results]}
    s = pd.DataFrame(d, columns=["left", "center", "right"])
    if write is True:
        file = open('ru_table.csv', 'w',encoding='utf-8-sig')
        s.to_csv(file, sep=';')
        file.close()
    else:
        pass
    if kwic is False:
        file = open('ru_table.csv', 'w', encoding='utf-8-sig')
        s = s.apply(f, axis=1)
        s.to_csv(file, sep=';')
    else:
        pass
    if s.empty:
        pass
        #print('Something went wrong: please try again!')
    else:
        return s

def main(query, corpus='main', tag='', n_results=10, write=False, kwic=True):
    
    request = urllib.request.quote(query.encode('windows-1251'))
    case = urllib.request.quote(tag.encode('windows-1251'))
    
    common_ur = create_request(corpus, request, case)
    #print(common_ur,'сайт')
    return get_table(get_all_pages(common_ur, n_results), n_results, write, kwic)
    

if __name__ == "__main__":
    args = sys.argv[1:]
    parser = argparse.ArgumentParser()
    parser.add_argument('corpus', type=str)
    parser.add_argument('query', type=str)
    parser.add_argument('tag', type=str)
    parser.add_argument('n_results', type=int)
    parser.add_argument('write', type=bool)
    parser.add_argument('kwic', type=bool)
    args = parser.parse_args(args)
    main(query, corpus, tag, n_results, write, kwic)
# Out:
# usage: ipykernel_launcher.py [-h] corpus query tag n_results write kwic
# ipykernel_launcher.py: error: the following arguments are required: query, tag, n_results, write, kwic
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Admin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
positive = pd.read_csv('pos_hypernymy.csv')
positive['child_context'] = ''
positive['parent_context'] = ''

# %%
positive['child_context'] = ''
positive['parent_context'] = ''

# %%
positive.head()
# Out:
#               child_id                      parent_id child_context  \
# 0        КРЕСТНЫЙ ОТЕЦ              КРЕСТНЫЙ РОДИТЕЛЬ
# 1    ОБМАН ПОКУПАТЕЛЕЙ      НАРУШЕНИЕ ПРАВИЛ ТОРГОВЛИ
# 2      ВОЕННАЯ ТАКТИКА  ТАКТИКА, ТАКТИЧЕСКИЕ ДЕЙСТВИЯ
# 3              УСМЕШКА                         УЛЫБКА
# 4  РЕЦЕПТУРА ЛЕКАРСТВА           РЕЦЕПТ ПРИГОТОВЛЕНИЯ
#
#   parent_context
# 0
# 1
# 2
# 3
# 4

# %%
example == type(lines)
# Out:
# True

# %%
counter = 0
for i in tqdm(range(len(positive.parent_id)), desc='Progress'):
    lines = main(positive.parent_id[i].lower(),n_results=14, kwic=False, write=False)
    if type(lines) == example:
        line = lines[0].replace('\xa0\xa0←…→\n   ','').replace('\xa0','')
        positive.loc[i,'parent_context'] = line
        print(line)
# Out:
# Progress:   0%|          | 0/37249 [00:00<?, ?it/s]
#
#
#
#
#
# Progress:   0%|          | 1/37249 [00:00<4:29:44,  2.30it/s]C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# 28 сентября 1998 г. за нарушение правил торговли должностное лицо было
# Progress:   0%|          | 2/37249 [00:01<5:05:29,  2.03it/s]
#
#
#
#
#
# Progress:   0%|          | 3/37249 [00:01<4:50:07,  2.14it/s]
# видишь его героя, непроизвольно появляется улыбка на лице.
# Progress:   0%|          | 4/37249 [00:02<5:05:58,  2.03it/s]
# Николасу Фламелю ― удалось-таки раскрыть рецепт приготовления философского камня, но он
# Progress:   0%|          | 5/37249 [00:02<5:53:42,  1.75it/s]
# Николасу Фламелю ― удалось-таки раскрыть рецепт приготовления философского камня, но он
# Progress:   0%|          | 6/37249 [00:03<6:21:11,  1.63it/s]
# заходить не следует, то пожилой посетитель начнёт допытываться у экскурсоводши, за
# Progress:   0%|          | 7/37249 [00:04<6:41:22,  1.55it/s]
# заходить не следует, то пожилой посетитель начнёт допытываться у экскурсоводши, за
# Progress:   0%|          | 8/37249 [00:05<7:29:52,  1.38it/s]
# Российской Федерации планирует ввести новый финансовый показатель ― «бивалютный индекс».
# Progress:   0%|          | 9/37249 [00:06<8:40:22,  1.19it/s]
# Российской Федерации планирует ввести новый финансовый показатель ― «бивалютный индекс».
# Progress:   0%|          | 10/37249 [00:06<7:06:25,  1.46it/s]
# Российской Федерации планирует ввести новый финансовый показатель ― «бивалютный индекс».
# Progress:   0%|          | 11/37249 [00:06<6:06:24,  1.69it/s]
# Российской Федерации планирует ввести новый финансовый показатель ― «бивалютный индекс».
# Progress:   0%|          | 12/37249 [00:08<7:49:15,  1.32it/s]
# Российской Федерации планирует ввести новый финансовый показатель ― «бивалютный индекс».
# Progress:   0%|          | 13/37249 [00:08<7:44:03,  1.34it/s]
# Progress:   0%|          | 37/37249 [00:27<7:28:04,  1.38it/s]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 38/37249 [00:28<8:39:37,  1.19it/s]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 39/37249 [00:29<10:09:28,  1.02it/s]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 40/37249 [00:31<10:28:14,  1.01s/it]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 41/37249 [00:31<10:10:31,  1.02it/s]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 42/37249 [00:32<9:49:27,  1.05it/s]
#  Это внешняя черта, но она говорит о
# Progress:   0%|          | 43/37249 [00:33<9:22:53,  1.10it/s]
# в лондонском Королевском колледже врачей глава организации Маргарет Чен сообщила о
# Progress:   0%|          | 44/37249 [00:35<11:00:19,  1.06s/it]
# в лондонском Королевском колледже врачей глава организации Маргарет Чен сообщила о
# Progress:   0%|          | 45/37249 [00:36<11:22:15,  1.10s/it]
# в лондонском Королевском колледже врачей глава организации Маргарет Чен сообщила о
# Progress:   0%|          | 46/37249 [00:36<9:46:48,  1.06it/s]
# в лондонском Королевском колледже врачей глава организации Маргарет Чен сообщила о
# Progress:   0%|          | 47/37249 [00:37<8:30:31,  1.21it/s]
# в лондонском Королевском колледже врачей глава организации Маргарет Чен сообщила о
# Progress:   0%|          | 48/37249 [00:38<8:22:14,  1.23it/s]
#
#
#
#
#
# Progress:   0%|          | 49/37249 [00:38<7:11:57,  1.44it/s]
#
#
#
#
#
# Progress:   0%|          | 50/37249 [00:38<6:09:40,  1.68it/s]
#
#
#
#
#
# Progress:   0%|          | 51/37249 [00:39<6:20:56,  1.63it/s]
#
#
#
#
#
# Progress:   0%|          | 52/37249 [00:40<6:58:22,  1.48it/s]
#
#
#
#
#
# Progress:   0%|          | 53/37249 [00:40<6:12:33,  1.66it/s]
#
#
#
#
#
# Progress:   0%|          | 54/37249 [00:41<6:01:39,  1.71it/s]
#
#
#
#
#
# Progress:   0%|          | 55/37249 [00:41<5:30:42,  1.87it/s]
#
#
#
#
#
# Progress:   0%|          | 56/37249 [00:42<5:08:53,  2.01it/s]
#
#
#
#
#
# Progress:   0%|          | 57/37249 [00:43<6:51:23,  1.51it/s]
#
#
#
#
#
# Progress:   0%|          | 58/37249 [00:44<7:19:45,  1.41it/s]
#
#
#
#
#
# Progress:   0%|          | 59/37249 [00:44<7:20:40,  1.41it/s]
#
#
#
#
#
# Progress:   0%|          | 60/37249 [00:45<6:19:37,  1.63it/s]
#
#
#
#
#
# Progress:   0%|          | 61/37249 [00:45<5:34:18,  1.85it/s]
#
#
#
#
#
# Progress:   0%|          | 62/37249 [00:45<5:03:29,  2.04it/s]
#
#
#
#
#
# Progress:   0%|          | 63/37249 [00:46<4:15:24,  2.43it/s]
#
#
#
#
#
# Progress:   0%|          | 64/37249 [00:46<3:59:21,  2.59it/s]
# происходит в том случае, если инфляция превышает за календарный период 6
# Progress:   0%|          | 65/37249 [00:46<3:56:29,  2.62it/s]
# порта приписки, который попросил его зайти по пути на промежуточную станцию
# Progress:   0%|          | 66/37249 [00:47<4:50:51,  2.13it/s]
#  Самый умеренный, средний в этом вопросе человек
# Progress:   0%|          | 67/37249 [00:48<5:23:26,  1.92it/s]
#
#
#
#
#
# Progress:   0%|          | 68/37249 [00:48<5:39:27,  1.83it/s]
#
#
#
#
#
# Progress:   0%|          | 69/37249 [00:49<6:17:50,  1.64it/s]
#
#
#
#
#
# Progress:   0%|          | 70/37249 [00:50<7:26:03,  1.39it/s]
#
#
#
#
#
# Progress:   0%|          | 71/37249 [00:50<6:05:27,  1.70it/s]
#
#
#
#
#
# Progress:   0%|          | 72/37249 [00:51<5:08:29,  2.01it/s]
#
#
#
#
#
# Progress:   0%|          | 73/37249 [00:51<4:28:31,  2.31it/s]
#
#
#
#
#
# Progress:   0%|          | 74/37249 [00:51<4:30:05,  2.29it/s]
#
#
#
#
#
# Progress:   0%|          | 75/37249 [00:52<4:33:56,  2.26it/s]
#
#
#
#
#
# Progress:   0%|          | 76/37249 [00:52<4:27:23,  2.32it/s]
#
#
#
#
#
# Progress:   0%|          | 77/37249 [00:53<4:59:21,  2.07it/s]
#
#
#
#
#
# Progress:   0%|          | 78/37249 [00:54<7:47:56,  1.32it/s]
#
#
#
#
#
# Progress:   0%|          | 79/37249 [00:56<9:55:13,  1.04it/s]
# а врач-интерн, окончивший высшее медицинское учебное заведение с красным дипломом
# Progress:   0%|          | 80/37249 [00:57<9:59:10,  1.03it/s]
# а врач-интерн, окончивший высшее медицинское учебное заведение с красным дипломом
# Progress:   0%|          | 81/37249 [00:58<10:05:06,  1.02it/s]
#
#
#
#
#
# Progress:   0%|          | 82/37249 [00:59<11:30:15,  1.11s/it]
#
#
#
#
#
# Progress:   0%|          | 83/37249 [01:01<12:48:30,  1.24s/it]
# жизнь ― на 14-м году вылезла онкология… эх…
# Progress:   0%|          | 84/37249 [01:02<12:20:27,  1.20s/it]
# Стоит только захотеть, а какое-нибудь финансовое нарушение всегда найдется.
# Progress:   0%|          | 85/37249 [01:03<11:36:34,  1.12s/it]
# Стоит только захотеть, а какое-нибудь финансовое нарушение всегда найдется.
# Progress:   0%|          | 86/37249 [01:04<11:26:05,  1.11s/it]
# группой конструкторов Нижегородского автозавода многоцелевой автомобиль ГАЗ-39371 «Водник».
# Progress:   0%|          | 87/37249 [01:04<9:51:04,  1.05it/s]
#
#
#
#
#
# Progress:   0%|          | 88/37249 [01:05<8:17:35,  1.24it/s]
# беспрецедентные возможности для технологического прогресса (биотехнология и биоинженерия) и революционных прорывов
# Progress:   0%|          | 89/37249 [01:05<7:08:33,  1.45it/s]
#
#
#
#
#
# Progress:   0%|          | 90/37249 [01:06<7:22:57,  1.40it/s]
#
#
#
#
#
# Progress:   0%|          | 91/37249 [01:06<6:09:15,  1.68it/s]
#
#
#
#
#
# Progress:   0%|          | 92/37249 [01:07<5:21:20,  1.93it/s]
#
#
#
#
#
# Progress:   0%|          | 93/37249 [01:07<6:00:30,  1.72it/s]
# те собрались, конечно, пытались ее успокоить, утихомирить, но Жанна орала и
# Progress:   0%|          | 94/37249 [01:08<6:14:23,  1.65it/s]
#  Стоит где-то затянуть по времени, сыграть неуверенно или
# Progress:   0%|          | 142/37249 [01:57<6:35:08,  1.57it/s]
#  Стоит где-то затянуть по времени, сыграть неуверенно или
# Progress:   0%|          | 143/37249 [01:58<6:11:17,  1.67it/s]
#
#
#
#
#
# Progress:   0%|          | 144/37249 [01:58<5:13:27,  1.97it/s]
#
#
#
#
#
# Progress:   0%|          | 145/37249 [01:58<4:51:26,  2.12it/s]
#
#
#
#
#
# Progress:   0%|          | 146/37249 [01:59<4:41:15,  2.20it/s]
#
#
#
#
#
# Progress:   0%|          | 147/37249 [01:59<5:16:26,  1.95it/s]
#
#
#
#
#
# Progress:   0%|          | 148/37249 [02:00<5:12:51,  1.98it/s]
#
#
#
#
#
# Progress:   0%|          | 149/37249 [02:00<4:55:26,  2.09it/s]
#
#
#
#
#
# Progress:   0%|          | 150/37249 [02:01<6:42:40,  1.54it/s]
#
#
#
#
#
# Progress:   0%|          | 151/37249 [02:03<9:21:11,  1.10it/s]
#
#
#
#
#
# Progress:   0%|          | 152/37249 [02:05<11:40:42,  1.13s/it]
#
#
#
#
#
# Progress:   0%|          | 153/37249 [02:05<10:22:08,  1.01s/it]
#
#
#
#
#
# Progress:   0%|          | 154/37249 [02:06<8:19:53,  1.24it/s]
#
#
#
#
#
# Progress:   0%|          | 155/37249 [02:06<6:41:12,  1.54it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 156/37249 [02:07<6:47:01,  1.52it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 157/37249 [02:07<7:15:49,  1.42it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 158/37249 [02:08<7:45:49,  1.33it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 159/37249 [02:09<7:49:12,  1.32it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 160/37249 [02:10<7:02:58,  1.46it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 161/37249 [02:10<7:41:52,  1.34it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 162/37249 [02:11<8:05:19,  1.27it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 163/37249 [02:12<9:03:18,  1.14it/s]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 164/37249 [02:14<10:51:55,  1.05s/it]
# сказать… Фильм не понапрасну носит звание Классики Советского Кино.
# Progress:   0%|          | 165/37249 [02:15<11:31:39,  1.12s/it]
#
#
#
#
#
# Progress:   0%|          | 166/37249 [02:16<12:01:30,  1.17s/it]
# работу уборщика (мойщика), существует жёсткая конкуренция со стороны, например, литовцев, эстонцев
# Progress:   0%|          | 167/37249 [02:18<12:02:42,  1.17s/it]
# работу уборщика (мойщика), существует жёсткая конкуренция со стороны, например, литовцев, эстонцев
# Progress:   0%|          | 168/37249 [02:19<12:43:57,  1.24s/it]
#  Небольшая компания DotHill в мае 2002 года
# Progress:   1%|          | 193/37249 [02:42<10:50:56,  1.05s/it]
#  Небольшая компания DotHill в мае 2002 года
# Progress:   1%|          | 194/37249 [02:43<10:35:44,  1.03s/it]
#
#
#
#
#
# Progress:   1%|          | 195/37249 [02:44<10:40:21,  1.04s/it]
#
#
#
#
#
# Progress:   1%|          | 196/37249 [02:45<10:24:00,  1.01s/it]
# святая воля.   Мне требуется хорошая ручка для письма.  Скоро именинница К[атя]
# Progress:   1%|          | 197/37249 [02:46<9:24:20,  1.09it/s]
#
#
#
#
#
# Progress:   1%|          | 198/37249 [02:46<7:46:53,  1.32it/s]
#
#
#
#
#
# Progress:   1%|          | 199/37249 [02:47<6:57:07,  1.48it/s]
#
#
#
#
#
# Progress:   1%|          | 200/37249 [02:47<6:10:48,  1.67it/s]
#
#
#
#
#
# Progress:   1%|          | 201/37249 [02:48<6:06:34,  1.68it/s]
#
#
#
#
#
# Progress:   1%|          | 202/37249 [02:49<7:34:00,  1.36it/s]
# всех полномочий властей субъектов РФ― город федерального значения (то есть Москвы
# Progress:   1%|          | 203/37249 [02:51<10:09:04,  1.01it/s]
# всех полномочий властей субъектов РФ― город федерального значения (то есть Москвы
# Progress:   1%|          | 204/37249 [02:52<10:41:01,  1.04s/it]
# всех полномочий властей субъектов РФ― город федерального значения (то есть Москвы
# Progress:   1%|          | 205/37249 [02:53<12:03:30,  1.17s/it]
#
#
#
#
#
# Progress:   1%|          | 206/37249 [02:55<12:40:19,  1.23s/it]
#
#
#
#
#
# Progress:   1%|          | 207/37249 [02:56<13:04:01,  1.27s/it]
#
#
#
#
#
# Progress:   1%|          | 208/37249 [02:56<10:12:35,  1.01it/s]
#
#
#
#
#
# Progress:   1%|          | 209/37249 [02:57<8:24:46,  1.22it/s]
# вопросы войны и мира;   л) внешнеэкономические отношения Российской Федерации;   м) оборона
# Progress:   1%|          | 210/37249 [02:57<6:54:52,  1.49it/s]
# вопросы войны и мира;   л) внешнеэкономические отношения Российской Федерации;   м) оборона
# Progress:   1%|          | 211/37249 [02:57<5:54:45,  1.74it/s]
# вопросы войны и мира;   л) внешнеэкономические отношения Российской Федерации;   м) оборона
# Progress:   1%|          | 212/37249 [02:58<5:14:34,  1.96it/s]
#
#
#
#
#
# Progress:   1%|          | 213/37249 [02:58<5:42:26,  1.80it/s]
#
#
#
#
#
# Progress:   1%|          | 214/37249 [02:59<4:46:39,  2.15it/s]
#
#
#
#
#
# Progress:   1%|          | 215/37249 [02:59<4:48:35,  2.14it/s]
#
#
#
#
#
# Progress:   1%|          | 216/37249 [03:00<4:59:06,  2.06it/s]
#  Предложение министра Ливанова не ставить оценку за грамотность выпускного сочинения
# Progress:   1%|          | 217/37249 [03:00<4:50:26,  2.13it/s]
#  Предложение министра Ливанова не ставить оценку за грамотность выпускного сочинения
# Progress:   1%|          | 218/37249 [03:01<5:54:53,  1.74it/s]
#
#
#
#
#
# Progress:   1%|          | 219/37249 [03:02<6:22:57,  1.61it/s]
# Лаишевский, Тетюшский) каждый четвёртый присяжный заседатель был мусульманином, а в целом
# Progress:   1%|          | 220/37249 [03:03<8:23:07,  1.23it/s]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 221/37249 [03:04<9:10:45,  1.12it/s]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 222/37249 [03:05<8:43:03,  1.18it/s]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 223/37249 [03:06<9:42:06,  1.06it/s]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 224/37249 [03:07<10:53:15,  1.06s/it]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 225/37249 [03:09<12:21:31,  1.20s/it]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 226/37249 [03:10<12:56:27,  1.26s/it]
# бедных стран, предотвращая тем самым чрезмерный наплыв мигрантов.
# Progress:   1%|          | 227/37249 [03:12<14:42:45,  1.43s/it]
#
#
#
#
#
# Progress:   1%|          | 228/37249 [03:13<12:02:39,  1.17s/it]
#
#
#
#
#
# Progress:   1%|          | 229/37249 [03:14<12:00:52,  1.17s/it]
#
#
#
#
#
# Progress:   1%|          | 230/37249 [03:16<14:48:36,  1.44s/it]
#
#
#
#
#
# Progress:   1%|          | 231/37249 [03:17<13:49:09,  1.34s/it]
#
#
#
#
#
# Progress:   1%|          | 232/37249 [03:18<14:11:10,  1.38s/it]
#
#
#
#
#
# Progress:   1%|          | 233/37249 [03:20<13:57:30,  1.36s/it]
#
#
#
#
#
# Progress:   1%|          | 234/37249 [03:21<15:18:33,  1.49s/it]
#
#
#
#
#
# Progress:   1%|          | 235/37249 [03:22<13:01:43,  1.27s/it]
#
#
#
#
#
# Progress:   1%|          | 236/37249 [03:23<12:07:21,  1.18s/it]
#
#
#
#
#
# Progress:   1%|          | 237/37249 [03:24<10:29:54,  1.02s/it]
#
#
#
#
#
# Progress:   1%|          | 238/37249 [03:24<9:12:39,  1.12it/s]
# хочется петь дифирамбы.   «- Меня вчера муха укусила.   ― Да.
# Progress:   1%|          | 239/37249 [03:25<8:08:41,  1.26it/s]
# хочется петь дифирамбы.   «- Меня вчера муха укусила.   ― Да.
# Progress:   1%|          | 240/37249 [03:26<7:49:48,  1.31it/s]
# аль-Фарук", что означает как раз "Избавитель", причём утверждается, что это прозвище
# Progress:   1%|          | 241/37249 [03:26<7:37:53,  1.35it/s]
#
#
#
#
#
# Progress:   1%|          | 242/37249 [03:27<7:39:50,  1.34it/s]
# давеча с шишкой пришел, весь опухлый ― это для здоровья, стало быть
# Progress:   1%|          | 243/37249 [03:28<8:05:11,  1.27it/s]
# давеча с шишкой пришел, весь опухлый ― это для здоровья, стало быть
# Progress:   1%|          | 244/37249 [03:29<7:48:42,  1.32it/s]
# месяцы, выпадающие на полевые и уборочные работы", ― заметил Валерий Драганов "Журналу
# Progress:   1%|          | 245/37249 [03:30<8:11:32,  1.25it/s]
# месяцы, выпадающие на полевые и уборочные работы", ― заметил Валерий Драганов "Журналу
# Progress:   1%|          | 246/37249 [03:31<9:30:56,  1.08it/s]
#
#
#
#
#
# Progress:   1%|          | 247/37249 [03:32<10:12:37,  1.01it/s]
#
#
#
#
#
# Progress:   1%|          | 248/37249 [03:33<10:13:28,  1.01it/s]
#
#
#
#
#
# Progress:   1%|          | 249/37249 [03:34<10:15:52,  1.00it/s]
#
#
#
#
#
# Progress:   1%|          | 250/37249 [03:35<10:04:44,  1.02it/s]
#
#
#
#
#
# Progress:   1%|          | 251/37249 [03:36<11:15:09,  1.09s/it]
#
#
#
#
#
# Progress:   1%|          | 252/37249 [03:37<11:18:46,  1.10s/it]
# которые предлагали подземный и подводный путепровод.
# Progress:   1%|          | 253/37249 [03:39<11:37:41,  1.13s/it]
# которые предлагали подземный и подводный путепровод.
# Progress:   1%|          | 254/37249 [03:40<12:51:38,  1.25s/it]
# не в серый, а в яркий по цвету пиджак, иначе ее
# Progress:   1%|          | 255/37249 [03:41<12:55:33,  1.26s/it]
# не в серый, а в яркий по цвету пиджак, иначе ее
# Progress:   1%|          | 256/37249 [03:42<11:43:54,  1.14s/it]
# не в серый, а в яркий по цвету пиджак, иначе ее
# Progress:   1%|          | 257/37249 [03:43<9:25:34,  1.09it/s]
# М. Игуменов, Б. А. Подливаев «Спортивная борьба».
# Progress:   1%|          | 258/37249 [03:44<9:12:10,  1.12it/s]
# М. Игуменов, Б. А. Подливаев «Спортивная борьба».
# Progress:   1%|          | 259/37249 [03:44<8:07:34,  1.26it/s]
# М. Игуменов, Б. А. Подливаев «Спортивная борьба».
# Progress:   1%|          | 260/37249 [03:45<7:24:48,  1.39it/s]
# М. Игуменов, Б. А. Подливаев «Спортивная борьба».
# Progress:   1%|          | 261/37249 [03:45<7:35:47,  1.35it/s]
# типа Spartan 2 (Device Family), микросхема xc 2 s 15 (Device
# Progress:   1%|          | 262/37249 [03:46<7:38:57,  1.34it/s]
# типа Spartan 2 (Device Family), микросхема xc 2 s 15 (Device
# Progress:   1%|          | 263/37249 [03:47<7:17:13,  1.41it/s]
# размещением в особой экономической зоне, ― льготное налогообложение, низкую стоимость аренды помещений
# Progress:   1%|          | 264/37249 [03:47<7:02:55,  1.46it/s]
#
#
#
#
#
# Progress:   1%|          | 265/37249 [03:48<5:46:52,  1.78it/s]
# лечебно-профилактических средств и другая спиртосодержащая продукция медицинского и ветеринарного назначения
# Progress:   1%|          | 266/37249 [03:49<7:57:00,  1.29it/s]
# лечебно-профилактических средств и другая спиртосодержащая продукция медицинского и ветеринарного назначения
# Progress:   1%|          | 267/37249 [03:50<9:07:27,  1.13it/s]
# лечебно-профилактических средств и другая спиртосодержащая продукция медицинского и ветеринарного назначения
# Progress:   1%|          | 268/37249 [03:51<10:28:33,  1.02s/it]
# лечебно-профилактических средств и другая спиртосодержащая продукция медицинского и ветеринарного назначения
# Progress:   1%|          | 269/37249 [03:52<10:23:33,  1.01s/it]
#  Россия накопила уникальный исторический опыт сосуществования и плодотворного
# Progress:   1%|          | 270/37249 [03:54<10:42:16,  1.04s/it]
# матча и билеты, на которых удар по мячу наносит хавбек "Ротора
# Progress:   1%|          | 271/37249 [03:55<10:54:19,  1.06s/it]
# матча и билеты, на которых удар по мячу наносит хавбек "Ротора
# Progress:   1%|          | 272/37249 [03:56<12:34:40,  1.22s/it]
# матча и билеты, на которых удар по мячу наносит хавбек "Ротора
# Progress:   1%|          | 273/37249 [03:57<11:02:54,  1.08s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 274/37249 [03:58<10:20:58,  1.01s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 275/37249 [03:59<9:59:49,  1.03it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 276/37249 [04:00<9:44:50,  1.05it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 277/37249 [04:01<9:31:58,  1.08it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 278/37249 [04:01<8:57:22,  1.15it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 279/37249 [04:02<9:48:58,  1.05it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 280/37249 [04:03<8:34:21,  1.20it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 281/37249 [04:04<7:51:49,  1.31it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 282/37249 [04:04<8:15:33,  1.24it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 283/37249 [04:05<7:40:33,  1.34it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 284/37249 [04:06<7:05:29,  1.45it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 285/37249 [04:06<7:05:41,  1.45it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 286/37249 [04:08<10:10:12,  1.01it/s]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 287/37249 [04:10<12:33:21,  1.22s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 288/37249 [04:12<14:11:31,  1.38s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 289/37249 [04:13<15:29:14,  1.51s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 290/37249 [04:15<14:33:55,  1.42s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 291/37249 [04:16<14:27:19,  1.41s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 292/37249 [04:18<15:30:33,  1.51s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 293/37249 [04:19<14:58:35,  1.46s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 294/37249 [04:21<15:12:23,  1.48s/it]
# обязательств (договорная), так и за причинение вреда (деликтная).
# Progress:   1%|          | 295/37249 [04:22<15:17:02,  1.49s/it]
#
#
#
#
#
# Progress:   1%|          | 296/37249 [04:23<14:04:51,  1.37s/it]
#
#
#
#
#
# Progress:   1%|          | 297/37249 [04:24<12:19:30,  1.20s/it]
#
#
#
#
#
# Progress:   1%|          | 298/37249 [04:24<9:46:56,  1.05it/s]
#
#
#
#
#
# Progress:   1%|          | 299/37249 [04:25<7:56:55,  1.29it/s]
#
#
#
#
#
# Progress:   1%|          | 300/37249 [04:25<6:08:52,  1.67it/s]
#
#
#
#
#
# Progress:   1%|          | 301/37249 [04:25<5:04:03,  2.03it/s]
#
#
#
#
#
# Progress:   1%|          | 302/37249 [04:25<4:20:05,  2.37it/s]
#
#
#
#
#
# Progress:   1%|          | 303/37249 [04:26<3:57:42,  2.59it/s]
#
#
#
#
#
# Progress:   1%|          | 304/37249 [04:26<3:32:52,  2.89it/s]
#
#
#
#
#
# Progress:   1%|          | 305/37249 [04:26<3:01:40,  3.39it/s]
#
#
#
#
#
# Progress:   1%|          | 306/37249 [04:26<2:54:25,  3.53it/s]
#
#
#
#
#
# Progress:   1%|          | 307/37249 [04:27<2:45:05,  3.73it/s]
#  Водопользование―не нарушать механизмов воспроизводства водных
# Progress:   1%|          | 308/37249 [04:27<3:13:48,  3.18it/s]
#
#
#
#
#
# Progress:   1%|          | 309/37249 [04:27<3:06:21,  3.30it/s]
#
#
#
#
#
# Progress:   1%|          | 310/37249 [04:28<2:56:27,  3.49it/s]
#
#
#
#
#
# Progress:   1%|          | 311/37249 [04:28<2:54:23,  3.53it/s]
#
#
#
#
#
# Progress:   1%|          | 312/37249 [04:28<2:53:40,  3.54it/s]
#
#
#
#
#
# Progress:   1%|          | 313/37249 [04:28<2:51:43,  3.58it/s]
# сейчас представилась ему очень отчётливо: тюремная камера, вода, крысы на кровати
# Progress:   1%|          | 314/37249 [04:29<3:16:52,  3.13it/s]
# сейчас представилась ему очень отчётливо: тюремная камера, вода, крысы на кровати
# Progress:   1%|          | 315/37249 [04:29<3:40:29,  2.79it/s]
# сейчас представилась ему очень отчётливо: тюремная камера, вода, крысы на кровати
# Progress:   1%|          | 316/37249 [04:30<3:47:04,  2.71it/s]
# сейчас представилась ему очень отчётливо: тюремная камера, вода, крысы на кровати
# Progress:   1%|          | 317/37249 [04:30<3:51:25,  2.66it/s]
# сейчас представилась ему очень отчётливо: тюремная камера, вода, крысы на кровати
# Progress:   1%|          | 318/37249 [04:30<4:08:03,  2.48it/s]
#
#
#
#
#
# Progress:   1%|          | 319/37249 [04:31<3:47:56,  2.70it/s]
#
#
#
#
#
# Progress:   1%|          | 320/37249 [04:31<3:28:26,  2.95it/s]
#
#
#
#
#
# Progress:   1%|          | 321/37249 [04:31<3:17:46,  3.11it/s]
#
#
#
#
#
# Progress:   1%|          | 322/37249 [04:32<3:07:06,  3.29it/s]
#
#
#
#
#
# Progress:   1%|          | 323/37249 [04:32<3:05:16,  3.32it/s]
#
#
#
#
#
# Progress:   1%|          | 324/37249 [04:32<2:57:47,  3.46it/s]
#
#
#
#
#
# Progress:   1%|          | 325/37249 [04:32<3:01:53,  3.38it/s]
#
#
#
#
#
# Progress:   1%|          | 326/37249 [04:33<2:56:24,  3.49it/s]
#
#
#
#
#
# Progress:   1%|          | 327/37249 [04:33<2:58:00,  3.46it/s]
# таких отношений вагон и маленькая тележка.
# Progress:   1%|          | 328/37249 [04:34<3:58:04,  2.58it/s]
# Раппопорт уже есть национальная итальянская кинопремия «Давид Донателло» за роль в
# Progress:   1%|          | 329/37249 [04:34<3:54:25,  2.62it/s]
# протокол о направлении на медицинское освидетельствование.
# Progress:   1%|          | 330/37249 [04:34<4:04:06,  2.52it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 331/37249 [04:35<4:04:00,  2.52it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 332/37249 [04:35<4:18:36,  2.38it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 333/37249 [04:36<4:11:28,  2.45it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 334/37249 [04:36<4:12:37,  2.44it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 335/37249 [04:37<4:13:50,  2.42it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 336/37249 [04:37<4:23:31,  2.33it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 337/37249 [04:37<4:20:42,  2.36it/s]
#  ). По их мнению, причина явления заключается в том, что
# Progress:   1%|          | 338/37249 [04:38<4:18:31,  2.38it/s]
# его грустные глаза, на седую прядь волос на лбу, на морщины
# Progress:   1%|          | 339/37249 [04:38<4:19:43,  2.37it/s]
# его грустные глаза, на седую прядь волос на лбу, на морщины
# Progress:   1%|          | 340/37249 [04:39<4:32:58,  2.25it/s]
# подсчеты показывают, что в холодный зимний месяц даже такая относительно небольшая
# Progress:   1%|          | 341/37249 [04:39<4:36:13,  2.23it/s]
# подсчеты показывают, что в холодный зимний месяц даже такая относительно небольшая
# Progress:   1%|          | 342/37249 [04:40<4:30:01,  2.28it/s]
# подсчеты показывают, что в холодный зимний месяц даже такая относительно небольшая
# Progress:   1%|          | 343/37249 [04:40<4:29:01,  2.29it/s]
#
#
#
#
#
# Progress:   1%|          | 344/37249 [04:40<4:06:39,  2.49it/s]
#
#
#
#
#
# Progress:   1%|          | 345/37249 [04:41<3:42:22,  2.77it/s]
#
#
#
#
#
# Progress:   1%|          | 346/37249 [04:41<3:28:31,  2.95it/s]
#
#
#
#
#
# Progress:   1%|          | 347/37249 [04:41<3:18:32,  3.10it/s]
#
#
#
#
#
# Progress:   1%|          | 348/37249 [04:41<3:09:30,  3.25it/s]
#
#
#
#
#
# Progress:   1%|          | 349/37249 [04:42<2:56:39,  3.48it/s]
#
#
#
#
#
# Progress:   1%|          | 350/37249 [04:42<2:46:48,  3.69it/s]
# социальные сети, почтовые сервисы и мобильный контент в единую пользовательскую среду
# Progress:   1%|          | 351/37249 [04:42<2:59:05,  3.43it/s]
# Ещё одно "детское" изобретение называется "Сигнал тревоги в пелёнках".
# Progress:   1%|          | 352/37249 [04:43<3:23:51,  3.02it/s]
# Ещё одно "детское" изобретение называется "Сигнал тревоги в пелёнках".
# Progress:   1%|          | 353/37249 [04:43<3:54:23,  2.62it/s]
# простыми распоряжениями соответствующих администраций.   3. Перспектива на будущее.   Мировой опыт, в
# Progress:   1%|          | 354/37249 [04:44<3:45:52,  2.72it/s]
# простыми распоряжениями соответствующих администраций.   3. Перспектива на будущее.   Мировой опыт, в
# Progress:   1%|          | 355/37249 [04:44<4:02:49,  2.53it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 356/37249 [04:44<4:16:45,  2.39it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 357/37249 [04:45<4:09:55,  2.46it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 358/37249 [04:45<3:54:08,  2.63it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 359/37249 [04:46<3:50:49,  2.66it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 360/37249 [04:46<4:03:08,  2.53it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 361/37249 [04:46<4:00:45,  2.55it/s]
# и Б) и это создает циклический процесс.
# Progress:   1%|          | 362/37249 [04:47<3:57:03,  2.59it/s]
#
#
#
#
#
# Progress:   1%|          | 363/37249 [04:47<3:33:15,  2.88it/s]
#
#
#
#
#
# Progress:   1%|          | 364/37249 [04:47<3:17:33,  3.11it/s]
#
#
#
#
#
# Progress:   1%|          | 365/37249 [04:48<3:05:34,  3.31it/s]
#
#
#
#
#
# Progress:   1%|          | 366/37249 [04:48<3:07:21,  3.28it/s]
#
#
#
#
#
# Progress:   1%|          | 367/37249 [04:48<3:01:13,  3.39it/s]
#
#
#
#
#
# Progress:   1%|          | 368/37249 [04:48<2:59:28,  3.42it/s]
#
#
#
#
#
# Progress:   1%|          | 369/37249 [04:49<2:44:36,  3.73it/s]
#
#
#
#
#
# Progress:   1%|          | 370/37249 [04:49<2:49:47,  3.62it/s]
#
#
#
#
#
# Progress:   1%|          | 371/37249 [04:49<3:00:27,  3.41it/s]
#
#
#
#
#
# Progress:   1%|          | 372/37249 [04:50<2:59:53,  3.42it/s]
# него оказалась сломанной ключица плюс черепно-мозговая травма.
# Progress:   1%|          | 373/37249 [04:50<3:22:33,  3.03it/s]
#
#
#
#
#
# Progress:   1%|          | 374/37249 [04:50<2:54:58,  3.51it/s]
#
#
#
#
#
# Progress:   1%|          | 375/37249 [04:50<2:36:12,  3.93it/s]
# лично не стал, т. к.   макроэкономика вещь в себе…   Что касается
# Progress:   1%|          | 376/37249 [04:51<3:00:04,  3.41it/s]
#
#
#
#
#
# Progress:   1%|          | 377/37249 [04:51<2:52:30,  3.56it/s]
#
#
#
#
#
# Progress:   1%|          | 378/37249 [04:51<2:54:54,  3.51it/s]
# простые: синильная кислота, циан ― известный ядовитый газ.
# Progress:   1%|          | 379/37249 [04:52<3:17:40,  3.11it/s]
# простые: синильная кислота, циан ― известный ядовитый газ.
# Progress:   1%|          | 380/37249 [04:52<3:26:56,  2.97it/s]
# например, много времени трачу на приготовление пищи: завтрак, обед и ужин
#  [Лилия Рэйман, nick]   Дмитрий, Вы понимаете, что государство все свои обязанности взвалило на
# Progress:  29%|██▊       | 10706/37249 [1:44:26<7:31:11,  1.02s/it]
#  [Лилия Рэйман, nick]   Дмитрий, Вы понимаете, что государство все свои обязанности взвалило на
# Progress:  29%|██▊       | 10707/37249 [1:44:28<9:02:57,  1.23s/it]
#  [Лилия Рэйман, nick]   Дмитрий, Вы понимаете, что государство все свои обязанности взвалило на
# Progress:  29%|██▊       | 10708/37249 [1:44:30<11:04:32,  1.50s/it]
#  [Лилия Рэйман, nick]   Дмитрий, Вы понимаете, что государство все свои обязанности взвалило на
# Progress:  29%|██▊       | 10709/37249 [1:44:32<11:47:00,  1.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-76588184e021> in <module>
#       1 counter = 0
#       2 for i in tqdm(range(len(positive.parent_id)), desc='Progress'):
# ----> 3     lines = main(positive.parent_id[i].lower(),n_results=14, kwic=False, write=False)
#       4     if type(lines) == example:
#       5         line = lines[0].replace('\xa0\xa0←…→\n   ','').replace('\xa0','')
#
# <ipython-input-19-a692a8906f06> in main(query, corpus, tag, n_results, write, kwic)
#      76     common_ur = create_request(corpus, request, case)
#      77     #print(common_ur,'сайт')
# ---> 78     return get_table(get_all_pages(common_ur, n_results), n_results, write, kwic)
#      79
#      80
#
# <ipython-input-19-a692a8906f06> in get_table(urls, n_results, write, kwic)
#      39     left_list = []
#      40     for url in urls:
# ---> 41         soup_url = urllib.request.urlopen(url)
#      42         soup = BeautifulSoup(soup_url, 'lxml')
#      43         for center_right in soup.select('tr > td > nobr'):
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
child_context = pd.read_csv('childs.csv')
child_context.head()
# Out:
#    Unnamed: 0             child_id                      parent_id  \
# 0           0        КРЕСТНЫЙ ОТЕЦ              КРЕСТНЫЙ РОДИТЕЛЬ
# 1           1    ОБМАН ПОКУПАТЕЛЕЙ      НАРУШЕНИЕ ПРАВИЛ ТОРГОВЛИ
# 2           2      ВОЕННАЯ ТАКТИКА  ТАКТИКА, ТАКТИЧЕСКИЕ ДЕЙСТВИЯ
# 3           3              УСМЕШКА                         УЛЫБКА
# 4           4  РЕЦЕПТУРА ЛЕКАРСТВА           РЕЦЕПТ ПРИГОТОВЛЕНИЯ
#
#                                        child_context  parent_context
# 0  его: «А разве Авель Енукидзе, крестный отец тв...             NaN
# 1  за продажу некачественных товаров и обман поку...             NaN
# 2       Военная тактика ― одно, а житейская ― совсем             NaN
# 3    Кривая усмешка шевельнула усики на губе Виталии             NaN
# 4                                                NaN             NaN

# %%
positive.child_context = child_context.child_context

# %%
final = positive.loc[(positive.child_context != '') & (positive.parent_context != '')]
#loc[(positive.child_context != '') & (positive.parent_context != '')]
#fillna('')#loc[(positive.child_context != '') & (positive.parent_context != '')]
#.loc[(positive.child_context != '') & (positive.parent_context != '')].head()

# %%
final = final[['child_context', 'parent_context']]

# %%
final['label'] = 1
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final.to_csv('pos_pairs.csv')

# %%
for i in range(len(positive.child_id)):
    
    if type(positive.loc[i,'parent_context']) != '':
        positive.loc[i,'child_context'] = positive.loc[i,'parent_context'].replace(positive.loc[i,'parent_id'].lower(), positive.loc[i,'child_id'].lower())
# Out:
# 0
# 1000
# 2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-fd85cd46adf8> in <module>
#       3         print(i)
#       4     if type(positive.loc[i,'parent_context']) != '':
# ----> 5         positive.loc[i,'child_context'] = positive.loc[i,'parent_context'].replace(positive.loc[i,'parent_id'].lower(), positive.loc[i,'child_id'].lower())
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     591             # actually do the set
#     592             self.obj._consolidate_inplace()
# --> 593             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#     594             self.obj._maybe_update_cacher(clear=True)
#     595
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in setitem(self, indexer, value)
#     941
#     942         # coerce and try to infer the dtypes of the result
# --> 943         values = self._try_coerce_and_cast_result(values, dtype)
#     944         if transpose:
#     945             values = values.T
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _try_coerce_and_cast_result(self, result, dtype)
#     745     def _try_coerce_and_cast_result(self, result, dtype=None):
#     746         result = self._try_coerce_result(result)
# --> 747         result = self._try_cast_result(result, dtype=dtype)
#     748         return result
#     749
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _try_cast_result(self, result, dtype)
#     708
#     709         # may need to change the dtype here
# --> 710         return maybe_downcast_to_dtype(result, dtype)
#     711
#     712     def _coerce_values(self, values):
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_downcast_to_dtype(result, dtype)
#     104     if isinstance(dtype, str):
#     105         if dtype == "infer":
# --> 106             inferred_type = lib.infer_dtype(ensure_object(result.ravel()), skipna=False)
#     107             if inferred_type == "boolean":
#     108                 dtype = "bool"
#
# KeyboardInterrupt:

# %%
positive.to_csv('dataset.csv')

# %%
positive.loc[positive.parent_context!=''].to_csv('dataset.csv')

# %%
example
# Out:
# pandas.core.series.Series

# %%
wiki_wiki = wikipediaapi.Wikipedia('ru')

# %%
counter = 0
for i in tqdm(range(len(positive.child_id)), desc='Progress'):
    lines = main(positive.child_id[i].lower(),n_results=14, kwic=False, write=False)
    if type(main(positive.child_id[i].lower(),n_results=14, kwic=False, write=False)) == type(example):
        line = main(positive.child_id[i].lower(),n_results=14, kwic=False, write=False)[0].replace('\xa0\xa0←…→\n   ','').replace('\xa0','')
        positive.loc[i,'child_context'] = line
        counter += 1
# Out:
# Page - Exists: True

# %%
positive.to_csv(os.getcwd()+"\\with_parents.csv" , encoding='utf-8-sig', header=True, index=False)

# %%
positive.head()
# Out:
#               child_id                      parent_id child_context  \
# 0        КРЕСТНЫЙ ОТЕЦ              КРЕСТНЫЙ РОДИТЕЛЬ
# 1    ОБМАН ПОКУПАТЕЛЕЙ      НАРУШЕНИЕ ПРАВИЛ ТОРГОВЛИ
# 2      ВОЕННАЯ ТАКТИКА  ТАКТИКА, ТАКТИЧЕСКИЕ ДЕЙСТВИЯ
# 3              УСМЕШКА                         УЛЫБКА
# 4  РЕЦЕПТУРА ЛЕКАРСТВА           РЕЦЕПТ ПРИГОТОВЛЕНИЯ
#
#                                       parent_context
# 0
# 1  28 сентября 1998 г. за нарушение правил торгов...
# 2
# 3  видишь его героя, непроизвольно появляется улы...
# 4  Николасу Фламелю ― удалось-таки раскрыть рецеп...
