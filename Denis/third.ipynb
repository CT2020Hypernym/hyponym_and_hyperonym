# %%
import pandas as pd
df = pd.read_csv('ru-isas-wiki-librusec-diff2.csv',  sep = "\t")

# %%
df.loc[80:100]
# Out:
#                           hyponym                     hypernym  freq
# 80               свобода владения         природными ресурсами     2
# 81               свобода владения                      ресурсы     2
# 82               депутат мартынюк                    активисты     4
# 83               депутат мартынюк                     активист     4
# 84                тюремные палачи                          чин     2
# 85                тюремные палачи                         чины     2
# 86        будущие президент кучма              днепропетровчан     6
# 87        будущие президент кучма  влиятельных днепропетровчан     6
# 88            кулинарным изделиям        новым видам продукции     4
# 89               присутствие воли                достоинствами     2
# 90               присутствие воли                  достоинство     2
# 91   пузырёк с красными чернилами                         цвет     2
# 92   пузырёк с красными чернилами                        цвета     2
# ...
