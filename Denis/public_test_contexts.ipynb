# %%
import pandas as pd
from tqdm import tqdm
import os

# %%
import urllib.request
import re
import argparse
import sys
from bs4 import BeautifulSoup
import pandas as pd
import unittest


def f(x):
    return x[0] + x[1] + x[2]


def create_request(corpus, request, case):
    url = 'http://search2.ruscorpora.ru/search.xml?env=alpha&mycorp=&mysent=&mysize=&mysentsize=&mydocsize=&dpp=&spp=&spd=&' \
          'text=lexform&mode=%s&sort=gr_tagging&lang=ru&nodia=1&req=%s&gramm1=%s&sem1=&sem-m' \
          'od1=sem&sem-mod1=sem2&flags1=&m1=&parent2=0&level2=0&min2=1&max2=1&lex2=&gramm2=&sem2=&sem-mod2=sem&se' \
          'm-mod2=sem2&flags2=&m2=&out=%s'
    common_url = url % (corpus, request, case, 'kwic')
    return common_url


def get_all_pages(common_url, results):
    pages = results // 10
    k = 0
    massive_of_links = []
    while k < pages:
        page = common_url + '&p=' + str(k)
        massive_of_links.append(page)
        k += 1
    return massive_of_links


def get_table(urls, n_results, write, kwic):
    center_right_list = []
    gram_list =[]
    center_list = []
    right_list = []
    left_list = []
    for url in urls:
        soup_url = urllib.request.urlopen(url)
        soup = BeautifulSoup(soup_url, 'lxml')
        for center_right in soup.select('tr > td > nobr'):
            center_right_list.append(center_right.text)
        for left in soup.select('tr > td > div > nobr'):
            left_list.append(left.text)
    center_list = center_right_list[0::2]
    right_list = center_right_list[1::2]
    if n_results == '':
        n_results = int(len(right_list))
    d = {"center": center_list[:n_results], "right": right_list[:n_results], "left": left_list[:n_results]}
    s = pd.DataFrame(d, columns=["left", "center", "right"])
    if write is True:
        file = open('ru_table.csv', 'w',encoding='utf-8-sig')
        s.to_csv(file, sep=';')
        file.close()
    else:
        pass
    if kwic is False:
        file = open('ru_table.csv', 'w', encoding='utf-8-sig')
        s = s.apply(f, axis=1)
        s.to_csv(file, sep=';')
    else:
        pass
    if s.empty:
        pass
        #print('Something went wrong: please try again!')
    else:
        return s

def main(query, corpus='main', tag='', n_results=10, write=False, kwic=True):
    
    request = urllib.request.quote(query.encode('windows-1251'))
    case = urllib.request.quote(tag.encode('windows-1251'))
    
    common_ur = create_request(corpus, request, case)
    #print(common_ur,'сайт')
    return get_table(get_all_pages(common_ur, n_results), n_results, write, kwic)
    

if __name__ == "__main__":
    args = sys.argv[1:]
    parser = argparse.ArgumentParser()
    parser.add_argument('corpus', type=str)
    parser.add_argument('query', type=str)
    parser.add_argument('tag', type=str)
    parser.add_argument('n_results', type=int)
    parser.add_argument('write', type=bool)
    parser.add_argument('kwic', type=bool)
    args = parser.parse_args(args)
    main(query, corpus, tag, n_results, write, kwic)
# Out:
# usage: ipykernel_launcher.py [-h] corpus query tag n_results write kwic
# ipykernel_launcher.py: error: the following arguments are required: query, tag, n_results, write, kwic
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Admin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
public_context = pd.DataFrame(columns = ['word','context'])

# %%
import pandas as pd 
tsv_file='nouns_public.tsv'
public_context=pd.read_table(tsv_file,sep='\t')
public_context.to_csv('public_nouns.csv')

# %%
public_context = pd.read_csv('public_nouns.csv',sep='\t',encoding='utf-8')

# %%
public_context = pd.read_csv('nouns_public.tsv',names=['word'])

# %%
public_context.head()
# Out:
#                word
# 0  АБДОМИНОПЛАСТИКА
# 1         АБСОРБЕНТ
# 2             АВАЛЬ
# 3          АВТАРКИЯ
# 4          АГНОСТИК

# %%
main(public_context.word[0].lower(),n_results=14, kwic=False, write=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-ca33e5d9da97> in <module>
# ----> 1 main(public_context.word[0].lower(),n_results=14, kwic=False, write=False)
#
# <ipython-input-16-a692a8906f06> in main(query, corpus, tag, n_results, write, kwic)
#      76     common_ur = create_request(corpus, request, case)
#      77     #print(common_ur,'сайт')
# ---> 78     return get_table(get_all_pages(common_ur, n_results), n_results, write, kwic)
#      79
#      80
#
# <ipython-input-16-a692a8906f06> in get_table(urls, n_results, write, kwic)
#      59     if kwic is False:
#      60         file = open('ru_table.csv', 'w', encoding='utf-8-sig')
# ---> 61         s = s.apply(f, axis=1)
#      62         s.to_csv(file, sep=';')
#      63     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     147         # dispatch to agg
#     148         if is_list_like(self.f) or is_dict_like(self.f):
# --> 149             return self.obj.aggregate(self.f, axis=self.axis, *self.args, **self.kwds)
#     150
#     151         # all empty
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6695         result = None
#    6696         try:
# -> 6697             result, how = self._aggregate(func, axis=axis, *args, **kwargs)
#    6698         except TypeError:
#    6699             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6706             # NDFrame.aggregate returns a tuple, and we need to transpose
#    6707             # only result
# -> 6708             result, how = self.T._aggregate(arg, *args, **kwargs)
#    6709             result = result.T if result is not None else result
#    6710             return result, how
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6709             result = result.T if result is not None else result
#    6710             return result, how
# -> 6711         return super()._aggregate(arg, *args, **kwargs)
#    6712
#    6713     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     562         elif is_list_like(arg):
#     563             # we require a list, but not an 'str'
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level, _axis=_axis), None
#     565         else:
#     566             result = None
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     619         # if we are empty
#     620         if not len(results):
# --> 621             raise ValueError("no results")
#     622
#     623         try:
#
# ValueError: no results

# %%
with open('nouns_public.tsv', 'r', encoding='utf-8') as f:
    i = 0
    for word in f:
        word = word[0:-1]
        print(word)
        public_context.loc[i, 'word'] = word.lower()
        context = main(word,n_results=14, kwic=False, write=False)
        if type(word) == example:
            public_context.loc[i, 'context'] = context
        else:
            public_context.loc[i, 'context'] = ''
        i += 1
# Out:
# АБДОМИНОПЛАСТИКА
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-5fb1f2620fd7> in <module>
#       5         print(word)
#       6         public_context.loc[i, 'word'] = word.lower()
# ----> 7         context = main(word,n_results=14, kwic=False, write=False)
#       8         if type(word) == example:
#       9             public_context.loc[i, 'context'] = context
#
# <ipython-input-16-a692a8906f06> in main(query, corpus, tag, n_results, write, kwic)
#      76     common_ur = create_request(corpus, request, case)
#      77     #print(common_ur,'сайт')
# ---> 78     return get_table(get_all_pages(common_ur, n_results), n_results, write, kwic)
#      79
#      80
#
# <ipython-input-16-a692a8906f06> in get_table(urls, n_results, write, kwic)
#      59     if kwic is False:
#      60         file = open('ru_table.csv', 'w', encoding='utf-8-sig')
# ---> 61         s = s.apply(f, axis=1)
#      62         s.to_csv(file, sep=';')
#      63     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     147         # dispatch to agg
#     148         if is_list_like(self.f) or is_dict_like(self.f):
# --> 149             return self.obj.aggregate(self.f, axis=self.axis, *self.args, **self.kwds)
#     150
#     151         # all empty
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6695         result = None
#    6696         try:
# -> 6697             result, how = self._aggregate(func, axis=axis, *args, **kwargs)
#    6698         except TypeError:
#    6699             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6706             # NDFrame.aggregate returns a tuple, and we need to transpose
#    6707             # only result
# -> 6708             result, how = self.T._aggregate(arg, *args, **kwargs)
#    6709             result = result.T if result is not None else result
#    6710             return result, how
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6709             result = result.T if result is not None else result
#    6710             return result, how
# -> 6711         return super()._aggregate(arg, *args, **kwargs)
#    6712
#    6713     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     562         elif is_list_like(arg):
#     563             # we require a list, but not an 'str'
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level, _axis=_axis), None
#     565         else:
#     566             result = None
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     607                 try:
#     608                     colg = self._gotitem(col, ndim=1, subset=obj.iloc[:, index])
# --> 609                     results.append(colg.aggregate(arg))
#     610                     keys.append(col)
#     611                 except (TypeError, DataError):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    3881         # Validate the axis parameter
#    3882         self._get_axis_number(axis)
# -> 3883         result, how = self._aggregate(func, *args, **kwargs)
#    3884         if result is None:
#    3885
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     562         elif is_list_like(arg):
#     563             # we require a list, but not an 'str'
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level, _axis=_axis), None
#     565         else:
#     566             result = None
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     592                 try:
#     593                     colg = self._gotitem(obj.name, ndim=1, subset=obj)
# --> 594                     results.append(colg.aggregate(a))
#     595
#     596                     # make sure we find a good name
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    3881         # Validate the axis parameter
#    3882         self._get_axis_number(axis)
# -> 3883         result, how = self._aggregate(func, *args, **kwargs)
#    3884         if result is None:
#    3885
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     323         raise AttributeError(
#     324             "'{arg}' is not a valid function for "
# --> 325             "'{cls}' object".format(arg=arg, cls=type(self).__name__)
#     326         )
#     327
#
# AttributeError: 'АБСОРБЕНТ
# ' is not a valid function for 'Series' object

# %%
with open('nouns_public.tsv', 'r', encoding='utf-8') as f:
    print(f.readline()[0:-1])
# Out:
# А

# %%
)public_context.head()
# Out:
#   File "<ipython-input-57-bdfb1987fcb8>", line 1
#     )public_context.head()
#     ^
# SyntaxError: invalid syntax

# %%
example = type(main('собака',n_results=14, kwic=False, write=False))
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
